# %% [markdown]
# File to make plots

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

# %% [markdown]
# ### Boxplots

# %%
def plot_boxplot(dailyValues):
    """
    Trace un boxplot à partir d'un dictionnaire dont les clés sont les 12 mois
    et les valeurs sont des listes de valeurs quotidiennes.
    """
    # Extraction des données sous forme de listes
    months = list(dailyValues.keys())
    data = list(dailyValues.values())
    
    # Création du boxplot
    plt.figure(figsize=(12, 6))
    sns.boxplot(data=data)
    
    # Configuration des labels
    plt.xticks(ticks=range(len(months)), labels=months, rotation=45)
    plt.xlabel("Months")
    plt.ylabel("Total precipitations (mm)")
    plt.title("Daily precipitations on Hans area")
    
    # Affichage du graphique
    plt.show()

# %% [markdown]
# Hans area daily

# %%
with open('/home/esauvat/Documents/NORCE/unseen-storm-forecasts/hans_storm/data/weathersets/results/continuous_hans-area-avg_0.25_daily.pkl', 'rb') as inp:
    dailyValues = pickle.load(inp)

# %%
plot_boxplot(dailyValues)

# %%
def plot_boxplot(values, threshold, path, title):
    """
    Trace un boxplot à partir d'un dictionnaire dont les clés sont les 12 mois
    et les valeurs sont des listes de paires (valeur, date).
    Affiche les dates des valeurs dépassant threshold.
    """
    months = list(values.keys())
    data = [[val for val, _ in values[month]] for month in months]
    
    plt.figure(figsize=(12, 6))
    sns.boxplot(data=data)
    
    # Ajout des annotations pour les valeurs dépassant threshold
    for month_idx, month in enumerate(months):
        for val, date in values[month]:
            if val > threshold:
                plt.text(month_idx, val, '  '+date, ha='left', fontsize=8, color='red')
    
    plt.xticks(ticks=range(len(months)), labels=months, rotation=45)
    plt.xlabel("Months")
    plt.ylabel("Precipitations (mm)")
    plt.title(title)
    
    plt.savefig(path)

    plt.show()

# %%
with open('/home/esauvat/Documents/NORCE/unseen-storm-forecasts/hans_storm/data/weathersets/results/continuous_hans-area-avg-daily_0.25_monthly.pkl', 'rb') as inp:
    dailyValues = pickle.load(inp)
with open('/home/esauvat/Documents/NORCE/unseen-storm-forecasts/hans_storm/data/weathersets/results/continuous_hans-area-avg-mean2_0.25_monthly.pkl', 'rb') as inp:
    mean2Values = pickle.load(inp)
with open('/home/esauvat/Documents/NORCE/unseen-storm-forecasts/hans_storm/data/weathersets/results/continuous_hans-area-avg-mean3_0.25_monthly.pkl', 'rb') as inp:
    mean3Values = pickle.load(inp)

# %%
plot_boxplot(dailyValues, 0.035, '/home/esauvat/Documents/NORCE/unseen-storm-forecasts/hans_storm/plots/daily_tp_hans-area.png', "Daily total precipitations over hans's area")

# %%
plot_boxplot(mean2Values, 0.03, '/home/esauvat/Documents/NORCE/unseen-storm-forecasts/hans_storm/plots/mean2_tp_hans-area.png', "2 days averaged total precipitations over hans's area")

# %%
plot_boxplot(mean3Values, 0.025, '/home/esauvat/Documents/NORCE/unseen-storm-forecasts/hans_storm/plots/mean3_tp_hans-area.png', "3 days averaged total precipitations over hans's area")

# %%
with open('/home/esauvat/Documents/NORCE/unseen-storm-forecasts/hans_storm/data/weathersets/results/continuous_hans-area-avg-daily_0.25_monthly-max.pkl', 'rb') as inp:
    maxDailyValues = pickle.load(inp)
with open('/home/esauvat/Documents/NORCE/unseen-storm-forecasts/hans_storm/data/weathersets/results/continuous_hans-area-avg-mean2_0.25_monthly-max.pkl', 'rb') as inp:
    maxMean2Values = pickle.load(inp)
with open('/home/esauvat/Documents/NORCE/unseen-storm-forecasts/hans_storm/data/weathersets/results/continuous_hans-area-avg-mean3_0.25_monthly-max.pkl', 'rb') as inp:
    maxMean3Values = pickle.load(inp)

# %%
plot_boxplot(maxDailyValues, 0.035, '/home/esauvat/Documents/NORCE/unseen-storm-forecasts/hans_storm/plots/max-daily_tp_hans-area.png', "Maximum daily total precipitations over hans's area")

# %%
plot_boxplot(maxMean2Values, 0.03, '/home/esauvat/Documents/NORCE/unseen-storm-forecasts/hans_storm/plots/max-mean2_tp_hans-area.png', "Maximum 2 days averaged total precipitations over hans's area")

# %%
plot_boxplot(maxMean3Values, 0.025, '/home/esauvat/Documents/NORCE/unseen-storm-forecasts/hans_storm/plots/max-mean3_tp_hans-area.png', "Maximum 3 days averaged total precipitations over hans's area")
