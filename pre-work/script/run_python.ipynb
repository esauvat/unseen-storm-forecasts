# %%
''' Import packages to access Weathersets when needed '''

import pickle
from weatherdata.classes import Weatherset
import xarray as xr
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Correlation

# %%
from simulation_script import correlation, ensemble_members_std

# %% [markdown]
# Correlation over 4 files dates

# %%
""" Select Weatherset """
wsPath = '/nird/projects/NS9873K/emile/unseen-storm-forecasts/weathersets/s2s_all-res.pkl'

# %%
''' mean2 correlation '''

with open(
        wsPath, 'rb') as inp:
    tpSet: Weatherset = pickle.load(
        inp)

treatmentType = "mean2"
correlation.main(
    tpSet, treatmentType, '2021-01-01')

with open(
        wsPath, 'wb') as outp:
    pickle.dump(
        tpSet, outp, pickle.HIGHEST_PROTOCOL)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 10
#       6     tpSet: Weatherset = pickle.load(
#       7         inp)
#       9 treatmentType = "mean2"
# ---> 10 correlation.hans_area_avg_correlation(
#      11     tpSet,
#      12     treatmentType,
#      13     '2021-01-01'
#      14 )
#      16 with open(
#      17         wsPath,
#      18         'wb') as outp:
#      19     pickle.dump(
#      20         tpSet,
#      21         outp,
#      22         pickle.HIGHEST_PROTOCOL)
#
# File /nird/projects/NS9873K/emile/unseen-storm-forecasts/script/correlation.py:309, in hans_area_avg_correlation(tpSet, treatmentType, lastDate)
#     301     fileNames = [  # 2 possible resolution
#     302         'tp24_0.25x0.25_' + date, 'tp24_0.5x0.5_' + date]
#     304     keys = list(
#     305         product(  # Apply set product -> 4 names associated to the date
# ...

# %%
# Plot the correlation 1 on 1
data = xr.open_dataarray(
    ('/nird/projects/NS9873K/emile/unseen-storm-forecasts/weathersets/results/'
     's2s-HA_avg-all_res-correlation_1_on_1-mean2.nc'))

ltimes = data.coords['time'].values
values = [data.sel(
    time=t).values for t in ltimes]

plt.figure(
    figsize=(12, 6))
sns.boxplot(
    data=values)

plt.xticks(
    ticks=range(
        len(
            ltimes)), labels=ltimes)
plt.xlabel(
    "Lead times")
plt.ylabel(
    "Correlation")
plt.title(
    "Correlation between ensemble members, averaged over 2 days")

plt.savefig(
    '/nird/projects/NS9873K/emile/unseen-storm-forecasts/plots/s2s-HA_avg-correlation-mean2.png')

plt.show()

# %%
''' mean3 correlation '''

with open(
        wsPath, 'rb') as inp:
    tpSet = pickle.load(
        inp)

treatmentType = "mean3"
correlation.main(
    tpSet, treatmentType, '2021-01-01')

with open(
        wsPath, 'wb') as outp:
    pickle.dump(
        tpSet, outp, pickle.HIGHEST_PROTOCOL)

# %%
# Plot the correlation 1 on 1
data = xr.open_dataarray(
    ('/nird/projects/NS9873K/emile/unseen-storm-forecasts/weathersets/results/'
     's2s-HA_avg-all_res-correlation_1_on_1-mean3.nc'))

ltimes = data.coords['time'].values
values = [data.sel(
    time=t).values for t in ltimes]

plt.figure(
    figsize=(12, 6))
sns.boxplot(
    data=values)

plt.xticks(
    ticks=range(
        len(
            ltimes)), labels=ltimes)
plt.xlabel(
    "Lead times")
plt.ylabel(
    "Correlation")
plt.title(
    "Correlation between ensemble members, averaged over 3 days")

plt.savefig(
    '/nird/projects/NS9873K/emile/unseen-storm-forecasts/plots/s2s-HA_avg-correlation-mean3.png')

plt.show()

# %% [markdown]
# ### Ensemble members standard deviation

# %%
""" Select Weatherset """
wsPath = '/nird/projects/NS9873K/emile/unseen-storm-forecasts/weathersets/s2s_all-res.pkl'

# %%
# mean 2 std
with open(
        wsPath, 'rb') as inp:
    tpSet = pickle.load(
        inp)

treatmentType = "mean2"
ensemble_members_std.compute_std(
    tpSet, '2021-01-01', treatmentType)

with open(
        wsPath, 'wb') as outp:
    pickle.dump(
        tpSet, outp, pickle.HIGHEST_PROTOCOL)

# %%
# Plot the mean2 std
data = xr.open_dataarray(
    ('/nird/projects/NS9873K/emile/unseen-storm-forecasts/weathersets/results/'
     's2s-HA_avg-all_res-ensemble_std-mean2.nc'))

ltimes = data.coords['time'].values
values = [data.sel(
    time=t).values for t in ltimes]

plt.figure(
    figsize=(12, 6))
sns.boxplot(
    data=values)

plt.xticks(
    ticks=range(
        len(
            ltimes)), labels=ltimes)
plt.xlabel(
    "Lead times")
plt.ylabel(
    "Standard deviation")
plt.title(
    "Standard deviation of ensemble members, averaged over 2 days")

plt.savefig(
    '/nird/projects/NS9873K/emile/unseen-storm-forecasts/plots/s2s-HA_avg-ensemble_std-mean2.png')

plt.show()

# %%
# Plot the mean2 std avg
data = xr.open_dataarray(
    ('/nird/projects/NS9873K/emile/unseen-storm-forecasts/weathersets/results/'
     's2s-HA_avg-all_res-ensemble_std-mean2.nc'))

ltimes = data.coords['time'].values
values = [data.sel(
    time=t).values.mean() for t in ltimes]

plt.figure(
    figsize=(12, 6))
plt.plot(
    values
)

plt.xticks(
    ticks=range(
        len(
            ltimes)), labels=ltimes)
plt.xlabel(
    "Lead times")
plt.ylabel(
    "Standard deviation")
plt.title(
    "Mean standard deviation of ensemble members, averaged over 2 days")

plt.savefig(
    '/nird/projects/NS9873K/emile/unseen-storm-forecasts/plots/s2s-HA_avg-ensemble_std_avg-mean2.png')

plt.show()

# %%
# mean 3 std
with open(
        wsPath, 'rb') as inp:
    tpSet = pickle.load(
        inp)

treatmentType = "mean3"
ensemble_members_std.compute_std(
    tpSet, '2021-01-01', treatmentType)

with open(
        wsPath, 'wb') as outp:
    pickle.dump(
        tpSet, outp, pickle.HIGHEST_PROTOCOL)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 8
#       4     tpSet = pickle.load(
#       5         inp)
#       7 treatmentType = "mean3"
# ----> 8 ensemble_members_std.compute_std(
#       9     tpSet, '2021-01-01', treatmentType)
#      11 with open(
#      12         wsPath, 'wb') as outp:
#      13     pickle.dump(
#      14         tpSet, outp, pickle.HIGHEST_PROTOCOL)
#
# File /nird/datapeak/NS9873K/emile/unseen-storm-forecasts/simulation_script/ensemble_members_std.py:110, in compute_std(tpSet, lastDate, treatmentType)
#     107 ##########################################
#     109 for date in initDates:
# --> 110     process_init_date(
#     111         tpSet, date, treatmentType)
#     113 result = xr.concat(
#     114     resList, dim='sim')
#     115 resList = []
#
# ...

# %%
# plot the mean 3 std
data = xr.open_dataarray(
    ('/nird/projects/NS9873K/emile/unseen-storm-forecasts/weathersets/results/'
     's2s-HA_avg-all_res-ensemble_std-mean3.nc'))

ltimes = data.coords['time'].values
values = [data.sel(
    time=t).values for t in ltimes]

plt.figure(
    figsize=(12, 6))
sns.boxplot(
    data=values)

plt.xticks(
    ticks=range(
        len(
            ltimes)), labels=ltimes)
plt.xlabel(
    "Lead times")
plt.ylabel(
    "Standard deviation")
plt.title(
    "Standard deviation of ensemble members, averaged over 3 days")

plt.savefig(
    '/nird/projects/NS9873K/emile/unseen-storm-forecasts/plots/s2s-HA_avg-ensemble_std-mean3.png')

plt.show()

# %%
# Plot the mean3 std avg
data = xr.open_dataarray(
    ('/nird/projects/NS9873K/emile/unseen-storm-forecasts/weathersets/results/'
     's2s-HA_avg-all_res-ensemble_std-mean3.nc'))

ltimes = data.coords['time'].values
values = [data.sel(
    time=t).values.mean() for t in ltimes]

plt.figure(
    figsize=(12, 6))
plt.plot(
    values
)

plt.xticks(
    ticks=range(
        len(
            ltimes)), labels=ltimes)
plt.xlabel(
    "Lead times")
plt.ylabel(
    "Standard deviation")
plt.title(
    "Mean standard deviation of ensemble members, averaged over 3 days")

plt.savefig(
    '/nird/projects/NS9873K/emile/unseen-storm-forecasts/plots/s2s-HA_avg-ensemble_std_avg-mean3.png')

plt.show()
